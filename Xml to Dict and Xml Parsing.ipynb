# %%
#Link to parse is 
#"http://www.icerocket.com/search?tab=blog&q=NATO+%22Brilliant+Jump%22&rss=1&p=1"

import xmltodict

with open('../../link.xml') as fd:
    doc = xmltodict.parse(fd.read())

# %%
doc
# Out:
# OrderedDict([(u'rss',
#               OrderedDict([(u'@version', u'2.0'),
#                            (u'@xmlns:dc', u'http://purl.org/dc/elements/1.1/'),
#                            (u'channel',
#                             OrderedDict([(u'title',
#                                           u'Icerocket blog search: NATO "Brilliant Jump"'),
#                                          (u'link',
#                                           u'http://www.icerocket.com/search?q=NATO+%22Brilliant+Jump%22'),
#                                          (u'description',
#                                           u'Blogs Search from IceRocket.com'),
#                                          (u'language', u'en-us'),
#                                          (u'copyright',
#                                           u'Copyright 2016, IceRocket.com'),
#                                          (u'item',
#                                           [OrderedDict([(u'title',
# ...

# %%
doc['rss']['channel']['title']
# Out:
# u'Icerocket blog search: NATO "Brilliant Jump"'

# %%
doc['rss']['channel']['link']
# Out:
# u'http://www.icerocket.com/search?q=NATO+%22Brilliant+Jump%22'

# %%
doc['rss']['channel']
# Out:
# OrderedDict([(u'title', u'Icerocket blog search: NATO "Brilliant Jump"'),
#              (u'link',
#               u'http://www.icerocket.com/search?q=NATO+%22Brilliant+Jump%22'),
#              (u'description', u'Blogs Search from IceRocket.com'),
#              (u'language', u'en-us'),
#              (u'copyright', u'Copyright 2016, IceRocket.com'),
#              (u'item',
#               [OrderedDict([(u'title',
#                              u'L\u2019Italia con la Nato in Lettonia: la questione di fondo'),
#                             (u'description',
#                              u'\xc8 necessaria una messa a punto per dare il giusto valore alla decisione del governo italiano di inviare 140 soldati italiani in Lettonia, come componente della forza Nato dislocata in quel Paese, al confine con la Federazione Russa. L\u2019orientamento della Nato a rafforzare militarmente i Paesi dell\u2019Eu <b>...</b>'),
#                             (u'link',
# ...

# %%
doc['rss']['channel']['description']
# Out:
# u'Blogs Search from IceRocket.com'
